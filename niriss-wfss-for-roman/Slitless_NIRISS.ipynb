# %% [markdown]
# ### Slitless Spectroscopy Example - JWST NIRISS Grism

# %% [markdown]
# This notebook shows exposure level processing of JWST NIRISS Grism rate images. It focuses on explaining the new WCS tools made available for JWST which help processing grism data.
#
# The assumption is that there one or more direct images were taken without moving the telescope and with the same instrument configuration as the grism images (same filter). This allows the distortion used models for the direct images to be included in the grism WCS pipeline. Essentially the direct image acts as a reference point in the WCS pipeline with its transform to sky applied in one part of the pipeline from sky to grism pixels and a transform from direct to grism image chained to it.

# %% [markdown]
# `sky` (RA, DEC, WAVE, ORDER) --> `direct_image` (IMX, IMY, WAVE, ORDER) --> `grism_image` (GRISMX, GRISMY)

# %% [markdown]
# #### Reference files
#
# - The transform from `sky` to `direct_image` uses a reference file with distortion model.
#
# - The transform from direct image to grism image is a polynomial which defines the spectral trace on the grism image. Include reference to Nor's paper.
#
# - A reference file containing the wavelength range for every spectral order
#
# All files are in ASDF format.

# %% [markdown]
# #### Processing workflow
#
# - The direct images (one or more dither observations) are processed through the Level 2 Imaging Pipeline and then the Level3 Imaging pipepine.
# - A source detection algorithm is run on the combined resampled image and a source catalog is produced.
# - The grism image is run through the Level 2 spectral pipeline using the source catalog produced by processing the direct images.
#  - The assign_wcs step constructs a WCS pipeline which passes through the following coordinate frames
#
#  `grism_image -> direct_image -> V3V3 -> sky`
#
#             `specwcs`     `distortion`

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import astropy
from astropy.io import fits

import numpy as np
import asdf
#pipeline
import jwst
from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Image2Pipeline
from jwst.pipeline import Image3Pipeline
from jwst.pipeline import Spec2Pipeline
from jwst.pipeline import Spec3Pipeline
#wcs
from jwst import assign_wcs
from jwst.assign_wcs import assign_wcs_step
from jwst.assign_wcs import AssignWcsStep
from jwst.extract_2d import Extract2dStep
#datamodels
from jwst import datamodels

# %%
specwcs = "jwst_niriss_specwcs_0018.asdf"

distortion = "jwst_niriss_distortion_0013.asdf"

filteroffset = "jwst_niriss_filteroffset_0002.asdf"

wavelength_range = "jwst_niriss_wavelengthrange_0002.asdf"

# %%
aspecwcs = asdf.open(specwcs)
asdf.info(specwcs, max_rows=200, max_cols=200)
# Out:
# 2022-09-05 18:11:17,896 - stpipe - WARNING - /var/folders/zd/pv7w8zxd3b9csmwxrwwg3gh80003pk/T/ipykernel_32909/2407714028.py:1: ResourceWarning: unclosed file <_io.BufferedReader name='jwst_niriss_specwcs_0018.asdf'>
#   aspecwcs = asdf.open(specwcs)
# root (AsdfObject)
# ├─asdf_library (Software)
# │ ├─author (str): The ASDF Developers
# │ ├─homepage (str): http://github.com/asdf-format/asdf
# │ ├─name (str): asdf
# │ └─version (str): 2.11.1
# ├─history (dict)
# │ ├─entries (list)
# │ │ └─[0] (HistoryEntry)
# │ │   ├─description (str): NIRISS Grism Parameters
# │ │   ├─software (Software)
# │ │   │ ├─author (str): Swara Ravindranath
# │ │   │ ├─homepage (str): https://github.com/spacetelescope/jwreftools
# │ │   │ ├─name (str): niriss_reftools.py
# │ │   │ └─version (str): 0.7.1
# │ │   └─time (datetime)
# │ └─extensions (list)
# │   ├─[0] (ExtensionMetadata)
# │   │ ├─extension_class (str): asdf.extension.BuiltinExtension
# │   │ └─software (Software)
# │   │   ├─name (str): asdf
# │   │   └─version (str): 2.11.1
# │   ├─[1] (ExtensionMetadata)
# │   │ ├─extension_class (str): asdf.extension._manifest.ManifestExtension
# │   │ ├─extension_uri (str): asdf://asdf-format.org/core/extensions/core-1.5.0
# │   │ └─software (Software)
# │   │   ├─name (str): asdf-astropy
# │   │   └─version (str): 0.2.1
# │   └─[2] (ExtensionMetadata)
# │     ├─extension_class (str): asdf.extension._manifest.ManifestExtension
# │     ├─extension_uri (str): asdf://asdf-format.org/transform/extensions/transform-1.5.0
# │     └─software (Software)
# │       ├─name (str): asdf-astropy
# │       └─version (str): 0.2.1
# ├─displ (list)
# │ ├─[0] (Polynomial1D)
# │ ├─[1] (Polynomial1D)
# │ ├─[2] (Polynomial1D)
# │ ├─[3] (Polynomial1D)
# │ └─[4] (Polynomial1D)
# ├─dispx (list)
# │ ├─[0] (list)
# │ │ ├─[0] (Polynomial2D)
# │ │ ├─[1] (Polynomial2D)
# │ │ └─[2] (Polynomial2D)
# │ ├─[1] (list)
# │ │ ├─[0] (Polynomial2D)
# │ │ ├─[1] (Polynomial2D)
# │ │ └─[2] (Polynomial2D)
# │ ├─[2] (list)
# │ │ ├─[0] (Polynomial2D)
# │ │ ├─[1] (Polynomial2D)
# │ │ └─[2] (Polynomial2D)
# │ ├─[3] (list)
# │ │ ├─[0] (Polynomial2D)
# │ │ ├─[1] (Polynomial2D)
# │ │ └─[2] (Polynomial2D)
# │ └─[4] (list)
# │   ├─[0] (Polynomial2D)
# │   ├─[1] (Polynomial2D)
# │   └─[2] (Polynomial2D)
# ├─dispy (list)
# │ ├─[0] (list)
# │ │ ├─[0] (Polynomial2D)
# │ │ ├─[1] (Polynomial2D)
# │ │ └─[2] (Polynomial2D)
# │ ├─[1] (list)
# │ │ ├─[0] (Polynomial2D)
# │ │ ├─[1] (Polynomial2D)
# │ │ └─[2] (Polynomial2D)
# │ ├─[2] (list)
# │ │ ├─[0] (Polynomial2D)
# │ │ ├─[1] (Polynomial2D)
# │ │ └─[2] (Polynomial2D)
# │ ├─[3] (list)
# │ │ ├─[0] (Polynomial2D)
# │ │ ├─[1] (Polynomial2D)
# │ │ └─[2] (Polynomial2D)
# │ └─[4] (list)
# │   ├─[0] (Polynomial2D)
# │   ├─[1] (Polynomial2D)
# │   └─[2] (Polynomial2D)
# ├─fwcpos_ref (float): 33.5667
# ├─invdispl (list)
# │ ├─[0] (Polynomial1D)
# │ ├─[1] (Polynomial1D)
# │ ├─[2] (Polynomial1D)
# │ ├─[3] (Polynomial1D)
# │ └─[4] (Polynomial1D)
# ├─meta (dict)
# │ ├─author (str): Swara Ravindranath
# │ ├─date (str): 2022-08-16T20:04:09.685
# │ ├─description (str): F200W dispersion model parameters
# │ ├─exposure (dict)
# │ │ └─type (str): NIS_WFSS
# │ ├─filename (str): jwst_niriss_specwcs_0024.asdf
# │ ├─history (str): NIRISS Grism Parameters
# │ ├─input_units (PrefixUnit)
# │ ├─instrument (dict)
# │ │ ├─detector (str): NIS
# │ │ ├─filter (str): GR150R
# │ │ ├─name (str): NIRISS
# │ │ └─pupil (str): F200W
# │ ├─model_type (str): NIRISSGrismModel
# │ ├─output_units (PrefixUnit)
# │ ├─pedigree (str): INFLIGHT 2022-05-22 2022-05-22
# │ ├─reftype (str): specwcs
# │ ├─telescope (str): JWST
# │ ├─title (str): NIRISS Reference File
# │ └─useafter (str): 2022-01-01T00:00:00
# └─orders (list)
#   ├─[0] (int): 1
#   ├─[1] (int): 2
#   ├─[2] (int): 3
#   ├─[3] (int): -1
#   └─[4] (int): 0

# %%
asdf.info(distortion, max_rows=200, max_cols=200)
# Out:
# root (AsdfObject)
# ├─asdf_library (Software)
# │ ├─author (str): The ASDF Developers
# │ ├─homepage (str): http://github.com/asdf-format/asdf
# │ ├─name (str): asdf
# │ └─version (str): 2.8.3
# ├─history (dict)
# │ ├─entries (list)
# │ │ └─[0] (HistoryEntry)
# │ │   ├─description (str): This file is being delivered because it is the wcs reference and distortion correction reference file. Documentation and scripts can be found in  (truncated)
# │ │   └─time (datetime)
# │ └─extensions (list)
# │   ├─[0] (ExtensionMetadata)
# │   │ ├─extension_class (str): asdf.extension.BuiltinExtension
# │   │ └─software (Software)
# │   │   ├─name (str): asdf
# │   │   └─version (str): 2.8.3
# │   ├─[1] (ExtensionMetadata)
# │   │ ├─extension_class (str): asdf.extension._manifest.ManifestExtension
# │   │ ├─extension_uri (str): asdf://asdf-format.org/transform/extensions/transform-1.5.0
# │   │ └─software (Software)
# │   │   ├─name (str): asdf-astropy
# │   │   └─version (str): 0.1.2
# │   └─[2] (ExtensionMetadata)
# │     ├─extension_class (str): asdf.extension._manifest.ManifestExtension
# │     ├─extension_uri (str): asdf://asdf-format.org/core/extensions/core-1.5.0
# │     └─software (Software)
# │       ├─name (str): asdf-astropy
# │       └─version (str): 0.1.2
# ├─bounding_box (list)
# │ ├─[0] (list)
# │ │ ├─[0] (int): 0
# │ │ └─[1] (int): 2047
# │ └─[1] (list)
# │   ├─[0] (int): 0
# │   └─[1] (int): 2047
# ├─meta (dict)
# │ ├─author (str): Tony Sohn
# │ ├─date (str): 2022-05-10T14:45:54.760
# │ ├─description (str): This is a distortion correction reference file.
# │ ├─exposure (dict)
# │ │ ├─p_exptype (str): NIS_IMAGE|NIS_AMI|NIS_WFSS|NIS_TACQ|NIS_FOCUS|NIS_TACONFIRM|
# │ │ └─type (str): NIS_IMAGE
# │ ├─filename (str): jwst_niriss_distortion_f200w.asdf
# │ ├─input_units (IrreducibleUnit)
# │ ├─instrument (dict)
# │ │ ├─detector (str): NIS
# │ │ ├─filter (str): CLEAR
# │ │ ├─name (str): NIRISS
# │ │ └─pupil (str): F200W
# │ ├─model_type (str): DistortionModel
# │ ├─output_units (Unit)
# │ ├─pedigree (str): INFLIGHT 2022-04-30 2022-05-01
# │ ├─reftype (str): distortion
# │ ├─subarray (dict)
# │ │ └─name (str): GENERIC
# │ ├─telescope (str): JWST
# │ ├─title (str): NIRISS distortion reference data.
# │ └─useafter (str): 2021-12-25T00:00:00
# └─model (CompoundModel)

# %%
asdf.info(wavelength_range, max_rows=500, max_cols=500)
# Out:
# root (AsdfObject)
# ├─asdf_library (Software)
# │ ├─author (str): Space Telescope Science Institute
# │ ├─homepage (str): http://github.com/spacetelescope/asdf
# │ ├─name (str): asdf
# │ └─version (str): 2.1.0.dev1417
# ├─history (dict)
# │ ├─entries (list)
# │ │ └─[0] (HistoryEntry)
# │ │   ├─description (str): Ground NIRCAM wavelength ranges, updated to include specific extraction orders per filter and a clearer structure for the wavelengthrange property
# │ │   ├─software (Software)
# │ │   │ ├─author (str): STScI
# │ │   │ ├─homepage (str): https://github.com/spacetelescope/jwreftools
# │ │   │ ├─name (str): niriss_reftools.py
# │ │   │ └─version (str): 0.7.1
# │ │   └─time (datetime)
# │ └─extensions (list)
# │   ├─[0] (ExtensionMetadata)
# │   │ ├─extension_class (str): asdf.extension.BuiltinExtension
# │   │ └─software (dict)
# │   │   ├─name (str): asdf
# │   │   └─version (str): 2.1.0.dev1417
# │   └─[1] (ExtensionMetadata)
# │     ├─extension_class (str): astropy.io.misc.asdf.extension.AstropyAsdfExtension
# │     └─software (dict)
# │       ├─name (str): astropy
# │       └─version (str): 3.1.dev22234
# ├─extract_orders (list)
# │ ├─[0] (list)
# │ │ ├─[0] (str): F090W
# │ │ └─[1] (list)
# │ │   ├─[0] (int): 1
# │ │   └─[1] (int): 2
# │ ├─[1] (list)
# │ │ ├─[0] (str): F115W
# │ │ └─[1] (list)
# │ │   └─[0] (int): 1
# │ ├─[2] (list)
# │ │ ├─[0] (str): F140M
# │ │ └─[1] (list)
# │ │   └─[0] (int): 1
# │ ├─[3] (list)
# │ │ ├─[0] (str): F150W
# │ │ └─[1] (list)
# │ │   └─[0] (int): 1
# │ ├─[4] (list)
# │ │ ├─[0] (str): F158M
# │ │ └─[1] (list)
# │ │   └─[0] (int): 1
# │ └─[5] (list)
# │   ├─[0] (str): F200W
# │   └─[1] (list)
# │     └─[0] (int): 1
# ├─meta (dict)
# │ ├─author (str): STScI
# │ ├─date (str): 2018-07-24T10:27:40.369
# │ ├─description (str): NIRISS WFSS Filter Wavelength Ranges
# │ ├─exposure (dict)
# │ │ └─type (str): NIS_WFSS
# │ ├─filename (str): niriss_wavelengthrange.asdf
# │ ├─input_units (PrefixUnit)
# │ ├─instrument (dict)
# │ │ ├─detector (str): NIS
# │ │ └─name (str): NIRISS
# │ ├─model_type (str): WavelengthrangeModel
# │ ├─module (str): N/A
# │ ├─output_units (PrefixUnit)
# │ ├─pedigree (str): ground
# │ ├─reftype (str): wavelengthrange
# │ ├─telescope (str): JWST
# │ ├─title (str): NIRISS WFSS wavelengthrange
# │ └─useafter (str): 2014-01-01T00:00:00
# ├─order (list)
# │ ├─[0] (int): -1
# │ ├─[1] (int): 0
# │ ├─[2] (int): 1
# │ ├─[3] (int): 2
# │ └─[4] (int): 3
# ├─wavelengthrange (list)
# │ ├─[0] (list)
# │ │ ├─[0] (int): -1
# │ │ ├─[1] (str): F150W
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.71
# │ ├─[1] (list)
# │ │ ├─[0] (int): -1
# │ │ ├─[1] (str): F158M
# │ │ ├─[2] (float): 1.41
# │ │ └─[3] (float): 1.74
# │ ├─[2] (list)
# │ │ ├─[0] (int): -1
# │ │ ├─[1] (str): F090W
# │ │ ├─[2] (float): 0.79
# │ │ └─[3] (float): 1.03
# │ ├─[3] (list)
# │ │ ├─[0] (int): -1
# │ │ ├─[1] (str): F115W
# │ │ ├─[2] (float): 0.97
# │ │ └─[3] (float): 1.32
# │ ├─[4] (list)
# │ │ ├─[0] (int): -1
# │ │ ├─[1] (str): F140M
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.52
# │ ├─[5] (list)
# │ │ ├─[0] (int): -1
# │ │ ├─[1] (str): F200W
# │ │ ├─[2] (float): 1.7
# │ │ └─[3] (float): 2.28
# │ ├─[6] (list)
# │ │ ├─[0] (int): 0
# │ │ ├─[1] (str): F150W
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.71
# │ ├─[7] (list)
# │ │ ├─[0] (int): 0
# │ │ ├─[1] (str): F158M
# │ │ ├─[2] (float): 1.41
# │ │ └─[3] (float): 1.74
# │ ├─[8] (list)
# │ │ ├─[0] (int): 0
# │ │ ├─[1] (str): F090W
# │ │ ├─[2] (float): 0.79
# │ │ └─[3] (float): 1.03
# │ ├─[9] (list)
# │ │ ├─[0] (int): 0
# │ │ ├─[1] (str): F115W
# │ │ ├─[2] (float): 0.97
# │ │ └─[3] (float): 1.32
# │ ├─[10] (list)
# │ │ ├─[0] (int): 0
# │ │ ├─[1] (str): F140M
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.52
# │ ├─[11] (list)
# │ │ ├─[0] (int): 0
# │ │ ├─[1] (str): F200W
# │ │ ├─[2] (float): 1.7
# │ │ └─[3] (float): 2.28
# │ ├─[12] (list)
# │ │ ├─[0] (int): 1
# │ │ ├─[1] (str): F150W
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.71
# │ ├─[13] (list)
# │ │ ├─[0] (int): 1
# │ │ ├─[1] (str): F158M
# │ │ ├─[2] (float): 1.41
# │ │ └─[3] (float): 1.74
# │ ├─[14] (list)
# │ │ ├─[0] (int): 1
# │ │ ├─[1] (str): F090W
# │ │ ├─[2] (float): 0.79
# │ │ └─[3] (float): 1.03
# │ ├─[15] (list)
# │ │ ├─[0] (int): 1
# │ │ ├─[1] (str): F115W
# │ │ ├─[2] (float): 0.97
# │ │ └─[3] (float): 1.32
# │ ├─[16] (list)
# │ │ ├─[0] (int): 1
# │ │ ├─[1] (str): F140M
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.52
# │ ├─[17] (list)
# │ │ ├─[0] (int): 1
# │ │ ├─[1] (str): F200W
# │ │ ├─[2] (float): 1.7
# │ │ └─[3] (float): 2.28
# │ ├─[18] (list)
# │ │ ├─[0] (int): 2
# │ │ ├─[1] (str): F150W
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.71
# │ ├─[19] (list)
# │ │ ├─[0] (int): 2
# │ │ ├─[1] (str): F158M
# │ │ ├─[2] (float): 1.41
# │ │ └─[3] (float): 1.74
# │ ├─[20] (list)
# │ │ ├─[0] (int): 2
# │ │ ├─[1] (str): F090W
# │ │ ├─[2] (float): 0.79
# │ │ └─[3] (float): 1.03
# │ ├─[21] (list)
# │ │ ├─[0] (int): 2
# │ │ ├─[1] (str): F115W
# │ │ ├─[2] (float): 0.97
# │ │ └─[3] (float): 1.32
# │ ├─[22] (list)
# │ │ ├─[0] (int): 2
# │ │ ├─[1] (str): F140M
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.52
# │ ├─[23] (list)
# │ │ ├─[0] (int): 2
# │ │ ├─[1] (str): F200W
# │ │ ├─[2] (float): 1.7
# │ │ └─[3] (float): 2.28
# │ ├─[24] (list)
# │ │ ├─[0] (int): 3
# │ │ ├─[1] (str): F150W
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.71
# │ ├─[25] (list)
# │ │ ├─[0] (int): 3
# │ │ ├─[1] (str): F158M
# │ │ ├─[2] (float): 1.41
# │ │ └─[3] (float): 1.74
# │ ├─[26] (list)
# │ │ ├─[0] (int): 3
# │ │ ├─[1] (str): F090W
# │ │ ├─[2] (float): 0.79
# │ │ └─[3] (float): 1.03
# │ ├─[27] (list)
# │ │ ├─[0] (int): 3
# │ │ ├─[1] (str): F115W
# │ │ ├─[2] (float): 0.97
# │ │ └─[3] (float): 1.32
# │ ├─[28] (list)
# │ │ ├─[0] (int): 3
# │ │ ├─[1] (str): F140M
# │ │ ├─[2] (float): 1.29
# │ │ └─[3] (float): 1.52
# │ └─[29] (list)
# │   ├─[0] (int): 3
# │   ├─[1] (str): F200W
# │   ├─[2] (float): 1.7
# │   └─[3] (float): 2.28
# └─waverange_selector (list)
#   ├─[0] (str): F090W
#   ├─[1] (str): F115W
#   ├─[2] (str): F140M
#   ├─[3] (str): F150W
#   ├─[4] (str): F158M
#   └─[5] (str): F200W

# %% [markdown]
# ##### Run Level2 and Level 3 of the Imaging Pipeline

# %%
fimage = 'jw01448013001_02106_00001_nis_rate.fits'
outim2 = Image2Pipeline.call(fimage)
# Out:
# 2022-09-05 18:04:13,533 - stpipe - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/dencheva/crds/references/jwst/niriss/jwst_niriss_pars-image2pipeline_0002.asdf
# 2022-09-05 18:04:13,554 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2022-09-05 18:04:13,556 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2022-09-05 18:04:13,558 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2022-09-05 18:04:13,560 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2022-09-05 18:04:13,561 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2022-09-05 18:04:13,563 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2022-09-05 18:04:13,642 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args ('jw01448013001_02106_00001_nis_rate.fits',).
# 2022-09-05 18:04:13,651 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}}}
# 2022-09-05 18:04:13,719 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'jw01448013001_02106_00001_nis_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2022-09-05 18:04:13,724 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/Users/dencheva/crds/references/jwst/niriss/jwst_niriss_area_0017.fits'.
# 2022-09-05 18:04:13,726 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2022-09-05 18:04:13,726 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-09-05 18:04:13,727 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2022-09-05 18:04:13,727 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2022-09-05 18:04:13,728 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/dencheva/crds/references/jwst/niriss/jwst_niriss_distortion_0013.asdf'.
# 2022-09-05 18:04:13,728 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2022-09-05 18:04:13,729 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/dencheva/crds/references/jwst/niriss/jwst_niriss_filteroffset_0002.asdf'.
# 2022-09-05 18:04:13,730 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/dencheva/crds/references/jwst/niriss/jwst_niriss_flat_0268.fits'.
# 2022-09-05 18:04:13,730 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2022-09-05 18:04:13,731 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2022-09-05 18:04:13,731 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2022-09-05 18:04:13,732 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2022-09-05 18:04:13,732 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-09-05 18:04:13,733 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2022-09-05 18:04:13,733 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2022-09-05 18:04:13,734 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/dencheva/crds/references/jwst/niriss/jwst_niriss_photom_0035.fits'.
# 2022-09-05 18:04:13,735 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2022-09-05 18:04:13,735 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2022-09-05 18:04:13,736 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2022-09-05 18:04:13,736 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-09-05 18:04:13,737 - stpipe.Image2Pipeline - INFO - Starting calwebb_image2 ...
# 2022-09-05 18:04:13,738 - stpipe.Image2Pipeline - INFO - Processing product jw01448013001_02106_00001_nis
# 2022-09-05 18:04:13,738 - stpipe.Image2Pipeline - INFO - Working on input jw01448013001_02106_00001_nis_rate.fits ...
# 2022-09-05 18:04:13,876 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(2048, 2048) from jw01448013001_02106_00001_nis_rate.fits>,).
# 2022-09-05 18:04:13,878 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2022-09-05 18:04:14,326 - stpipe.Image2Pipeline.assign_wcs - INFO - Offsets from filteroffset file are 2.119, -1.0476
# 2022-09-05 18:04:14,505 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  215.778071054 53.224609970 215.785524769 53.187469291 215.847029385 53.192061634 215.839649774 53.229181297
# 2022-09-05 18:04:14,506 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  215.778071054 53.224609970 215.785524769 53.187469291 215.847029385 53.192061634 215.839649774 53.229181297
# 2022-09-05 18:04:14,506 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2022-09-05 18:04:14,611 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2022-09-05 18:04:14,686 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(2048, 2048) from jw01448013001_02106_00001_nis_rate.fits>,).
# 2022-09-05 18:04:14,687 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2022-09-05 18:04:15,145 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2022-09-05 18:04:15,231 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(2048, 2048) from jw01448013001_02106_00001_nis_rate.fits>,).
# 2022-09-05 18:04:15,233 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2022-09-05 18:04:15,276 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /Users/dencheva/crds/references/jwst/niriss/jwst_niriss_photom_0035.fits
# 2022-09-05 18:04:15,277 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /Users/dencheva/crds/references/jwst/niriss/jwst_niriss_area_0017.fits
# 2022-09-05 18:04:15,385 - stpipe.Image2Pipeline.photom - INFO - Using instrument: NIRISS
# 2022-09-05 18:04:15,386 - stpipe.Image2Pipeline.photom - INFO -  detector: NIS
# 2022-09-05 18:04:15,386 - stpipe.Image2Pipeline.photom - INFO -  exp_type: NIS_IMAGE
# 2022-09-05 18:04:15,387 - stpipe.Image2Pipeline.photom - INFO -  filter: CLEAR
# 2022-09-05 18:04:15,387 - stpipe.Image2Pipeline.photom - INFO -  pupil: F200W
# 2022-09-05 18:04:15,449 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2022-09-05 18:04:15,452 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 0.264704
# 2022-09-05 18:04:15,477 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2022-09-05 18:04:15,567 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(2048, 2048) from jw01448013001_02106_00001_nis_rate.fits>,).
# 2022-09-05 18:04:15,569 - stpipe.Image2Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}
# 2022-09-05 18:04:15,570 - stpipe.Image2Pipeline.resample - INFO - Step skipped.
# 2022-09-05 18:04:15,575 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2022-09-05 18:04:15,576 - stpipe.Image2Pipeline - INFO - Finished processing product jw01448013001_02106_00001_nis
# 2022-09-05 18:04:15,578 - stpipe.Image2Pipeline - INFO - ... ending calwebb_image2
# 2022-09-05 18:04:15,579 - stpipe.Image2Pipeline - INFO - Results used CRDS context: jwst_0968.pmap
# 2022-09-05 18:04:16,170 - stpipe.Image2Pipeline - INFO - Saved model in jw01448013001_02106_00001_nis_cal.fits
# 2022-09-05 18:04:16,170 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %%
Image3Pipeline.from_cmdline(["calwebb_image3", "jw01448013001_02106_00001_nis_cal.fits"])
# Out:
# 2022-09-05 18:04:31,980 - stpipe - INFO - PARS-TWEAKREGSTEP parameters found: /Users/dencheva/crds/references/jwst/niriss/jwst_niriss_pars-tweakregstep_0001.asdf
# 2022-09-05 18:04:31,996 - stpipe - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /Users/dencheva/crds/references/jwst/niriss/jwst_niriss_pars-outlierdetectionstep_0002.asdf
# 2022-09-05 18:04:32,019 - CRDS - ERROR -  Error determining best reference for 'pars-sourcecatalogstep'  =   No match found.
# 2022-09-05 18:04:32,034 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2022-09-05 18:04:32,035 - stpipe.Image3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2022-09-05 18:04:32,037 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2022-09-05 18:04:32,039 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2022-09-05 18:04:32,040 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2022-09-05 18:04:32,042 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2022-09-05 18:04:32,044 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2022-09-05 18:04:32,137 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('jw01448013001_02106_00001_nis_cal.fits',).
# 2022-09-05 18:04:32,148 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'tweakreg': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalogs': False, 'catalog_format': 'ecsv', 'kernel_fwhm': 1.078, 'snr_threshold': 10, 'brightest': 100, 'peakmax': None, 'enforce_user_order': False, 'expand_refcat': False, 'minobj': 15, 'searchrad': 1.0, 'use2dhist': True, 'separation': 0.5, 'tolerance': 1.0, 'xoffset': 0.0, 'yoffset': 0.0, 'fitgeometry': 'general', 'nclip': 3, 'sigma': 3.0, 'align_to_gaia': False, 'gaia_catalog': 'GAIADR2', 'min_gaia': 5, 'save_gaia_catalog': False}, 'skymatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'skymethod': 'match', 'match_down': True, 'subtract': False, 'stepsize': None, 'skystat': 'mode', 'dqbits': '~DO_NOT_USE+NON_SCIENCE', 'lower': None, 'upper': None, 'nclip': 5, 'lsigma': 4.0, 'usigma': 4.0, 'binwidth': 0.1}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '2.1 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'source_catalog': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}}}
# 2022-09-05 18:04:32,292 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'jw01448013001_02106_00001_nis_cal.fits' reftypes = ['abvegaoffset', 'apcorr', 'drizpars']
# 2022-09-05 18:04:32,296 - stpipe.Image3Pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/Users/dencheva/crds/references/jwst/niriss/jwst_niriss_abvegaoffset_0003.asdf'.
# 2022-09-05 18:04:32,297 - stpipe.Image3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/dencheva/crds/references/jwst/niriss/jwst_niriss_apcorr_0005.fits'.
# 2022-09-05 18:04:32,297 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/dencheva/crds/references/jwst/niriss/jwst_niriss_drizpars_0002.fits'.
# 2022-09-05 18:04:32,299 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2022-09-05 18:04:32,430 - stpipe.Image3Pipeline - WARNING - Turning 'skymatch' step off for a single input image when 'skymethod' is 'match'
# 2022-09-05 18:04:32,509 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ImageModel(2048, 2048) from jw01448013001_02106_00001_nis_cal.fits>,).
# 2022-09-05 18:04:32,512 - stpipe.Image3Pipeline.resample - INFO - Step resample parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'i2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}
# 2022-09-05 18:04:32,558 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /Users/dencheva/crds/references/jwst/niriss/jwst_niriss_drizpars_0002.fits
# 2022-09-05 18:04:32,589 - stpipe.Image3Pipeline.resample - INFO - Driz parameter kernel: square
# 2022-09-05 18:04:32,590 - stpipe.Image3Pipeline.resample - INFO - Driz parameter pixfrac: 1.0
# 2022-09-05 18:04:32,590 - stpipe.Image3Pipeline.resample - INFO - Driz parameter fillval: INDEF
# 2022-09-05 18:04:32,591 - stpipe.Image3Pipeline.resample - INFO - Driz parameter weight_type: ivm
# 2022-09-05 18:04:32,766 - stpipe.Image3Pipeline.resample - INFO - Resampling science data
# 2022-09-05 18:04:34,918 - stpipe.Image3Pipeline.resample - INFO - Drizzling (2048, 2048) --> (2063, 2040)
# 2022-09-05 18:04:35,640 - stpipe.Image3Pipeline.resample - INFO - Resampling var_rnoise
# 2022-09-05 18:04:37,580 - stpipe.Image3Pipeline.resample - INFO - Drizzling (2048, 2048) --> (2063, 2040)
# 2022-09-05 18:04:38,371 - stpipe.Image3Pipeline.resample - INFO - Resampling var_poisson
# 2022-09-05 18:04:40,333 - stpipe.Image3Pipeline.resample - INFO - Drizzling (2048, 2048) --> (2063, 2040)
# 2022-09-05 18:04:41,194 - stpipe.Image3Pipeline.resample - INFO - Resampling var_flat
# 2022-09-05 18:04:43,348 - stpipe.Image3Pipeline.resample - INFO - Drizzling (2048, 2048) --> (2063, 2040)
# 2022-09-05 18:04:44,269 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  215.778022627 53.224775236 215.785500545 53.187470837 215.847070325 53.191881912 215.839645268 53.229190154
# 2022-09-05 18:04:44,784 - stpipe.Image3Pipeline.resample - INFO - Saved model in jw01448013001_02106_00001_nis_i2d.fits
# 2022-09-05 18:04:44,784 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2022-09-05 18:04:44,872 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<ImageModel(2063, 2040) from jw01448013001_02106_00001_nis_i2d.fits>,).
# 2022-09-05 18:04:44,874 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'cat', 'search_output_file': True, 'input_dir': '', 'bkg_boxsize': 1000, 'kernel_fwhm': 2.0, 'snr_threshold': 3.0, 'npixels': 25, 'deblend': False, 'aperture_ee1': 30, 'aperture_ee2': 50, 'aperture_ee3': 70, 'ci1_star_threshold': 2.0, 'ci2_star_threshold': 1.8}
# 2022-09-05 18:04:44,905 - stpipe.Image3Pipeline.source_catalog - INFO - Using APCORR reference file: /Users/dencheva/crds/references/jwst/niriss/jwst_niriss_apcorr_0005.fits
# 2022-09-05 18:04:44,919 - stpipe.Image3Pipeline.source_catalog - INFO - Using ABVEGAOFFSET reference file: /Users/dencheva/crds/references/jwst/niriss/jwst_niriss_abvegaoffset_0003.asdf
# 2022-09-05 18:04:44,920 - stpipe.Image3Pipeline.source_catalog - INFO - Instrument: NIRISS
# 2022-09-05 18:04:44,921 - stpipe.Image3Pipeline.source_catalog - INFO - Detector: NIS
# 2022-09-05 18:04:44,921 - stpipe.Image3Pipeline.source_catalog - INFO - Filter: CLEAR
# 2022-09-05 18:04:44,922 - stpipe.Image3Pipeline.source_catalog - INFO - Pupil: F200W
# 2022-09-05 18:04:44,923 - stpipe.Image3Pipeline.source_catalog - INFO - Subarray: FULL
# 2022-09-05 18:04:45,000 - stpipe.Image3Pipeline.source_catalog - INFO - AB to Vega magnitude offset 1.68884
# 2022-09-05 18:04:47,606 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 634 sources
# 2022-09-05 18:04:48,349 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: jw01448013001_02106_00001_nis_cat.ecsv
# 2022-09-05 18:04:48,551 - stpipe.Image3Pipeline.source_catalog - INFO - Saved model in jw01448013001_02106_00001_nis_segm.fits
# 2022-09-05 18:04:48,552 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote segmentation map: jw01448013001_02106_00001_nis_segm.fits
# 2022-09-05 18:04:48,579 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2022-09-05 18:04:48,580 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %% [markdown]
# Level 3 processing produces a catalog - jw01448013001_02106_00001_nis_cat.ecsv.
#
# The output image from L3 pipeline is jw01448013001_02106_00001_nis_i2d.fits.

# %% [markdown]
# ##### Run the assign_wcs step on the spectral image. It uses the reference files to chain all transforms and generate a WCS pipeline

# %%
# Process one grism observation using the new reference file
#specwcs = "jwst_niriss_specwcs_0012.asdf"
fname = "jw01448013001_02105_00001_nis_rate.fits"
astep = AssignWcsStep()
out = astep.call(fname)
# Out:
# 2022-09-05 18:06:23,599 - stpipe.AssignWcsStep - INFO - AssignWcsStep instance created.
# 2022-09-05 18:06:23,876 - stpipe.AssignWcsStep - INFO - AssignWcsStep instance created.
# 2022-09-05 18:06:23,971 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep running with args ('jw01448013001_02105_00001_nis_rate.fits',).
# 2022-09-05 18:06:23,973 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2022-09-05 18:06:25,414 - stpipe.AssignWcsStep - INFO - Added Barycentric velocity correction: 0.999965786033709
# 2022-09-05 18:06:25,789 - stpipe.AssignWcsStep - INFO - COMPLETED assign_wcs
# 2022-09-05 18:06:25,808 - stpipe.AssignWcsStep - INFO - Results used CRDS context: jwst_0968.pmap
# 2022-09-05 18:06:25,809 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep done

# %% [markdown]
# ##### Extract_2d
#
# Run the extract_2d step in the pipeline. It uses the source catalog and the WCS object to find the location of the trace for each slit and order and extract a cutout with the corresponding WCS. The limits of the cutpout are defined from the segmentation map of the image on the sky. The corners on the sky are transformed to the grism detector using the inverse WCS transform.

# %%
out.meta.source_catalog="jw01448013001_02106_00001_nis_cat.ecsv"
exout = Extract2dStep.call(out, wfss_mmag_extract=21)
exout.save("jw01448013001_02105_00001_nis_ex2d.fits")
# Out:
# 2022-09-05 18:06:42,059 - stpipe.Extract2dStep - INFO - Extract2dStep instance created.
# 2022-09-05 18:06:42,148 - stpipe.Extract2dStep - INFO - Step Extract2dStep running with args (<ImageModel(2048, 2048) from jw01448013001_02105_00001_nis_rate.fits>,).
# 2022-09-05 18:06:42,150 - stpipe.Extract2dStep - INFO - Step Extract2dStep parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_name': None, 'extract_orders': None, 'grism_objects': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'wfss_mmag_extract': 21, 'wfss_nbright': 1000}
# 2022-09-05 18:06:42,175 - stpipe.Extract2dStep - INFO - EXP_TYPE is NIS_WFSS
# 2022-09-05 18:06:42,202 - stpipe.Extract2dStep - INFO - Extracting objects < abmag = 21
# 2022-09-05 18:06:42,203 - stpipe.Extract2dStep - INFO - Getting objects from jw01448013001_02106_00001_nis_cat.ecsv
# 2022-09-05 18:06:42,535 - stpipe.Extract2dStep - INFO - Partial order on detector for obj: 33 order: 1
# 2022-09-05 18:06:42,551 - stpipe.Extract2dStep - INFO - Partial order on detector for obj: 35 order: 1
# 2022-09-05 18:06:42,935 - stpipe.Extract2dStep - INFO - Total of 30 grism objects defined
# 2022-09-05 18:06:42,938 - stpipe.Extract2dStep - INFO - Grism object list created from source catalog: jw01448013001_02106_00001_nis_cat.ecsv
# 2022-09-05 18:06:42,938 - stpipe.Extract2dStep - INFO - Extracting 30 grism objects
# 2022-09-05 18:06:42,974 - stpipe.Extract2dStep - INFO - YYY, (1128, 1352), 1128
# 2022-09-05 18:06:43,199 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 414 order: 1:
# 2022-09-05 18:06:43,199 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:35.2907441478641, xmax:45.2907441478641), (ymin:1128, ymax:1352)
# 2022-09-05 18:06:43,459 - stpipe.Extract2dStep - INFO - YYY, (1173, 1381), 1173
# 2022-09-05 18:06:43,677 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 426 order: 1:
# 2022-09-05 18:06:43,678 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:790, xmax:910), (ymin:1173, ymax:1381)
# 2022-09-05 18:06:43,812 - stpipe.Extract2dStep - INFO - YYY, (1273, 1460), 1273
# 2022-09-05 18:06:44,026 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 465 order: 1:
# 2022-09-05 18:06:44,027 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1467.289172012932, xmax:1477.289172012932), (ymin:1273, ymax:1460)
# 2022-09-05 18:06:44,160 - stpipe.Extract2dStep - INFO - YYY, (742, 916), 742
# 2022-09-05 18:06:44,372 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 287 order: 1:
# 2022-09-05 18:06:44,373 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:675.799810511557, xmax:685.799810511557), (ymin:742, ymax:916)
# 2022-09-05 18:06:44,503 - stpipe.Extract2dStep - INFO - YYY, (1486, 1685), 1486
# 2022-09-05 18:06:44,715 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 542 order: 1:
# 2022-09-05 18:06:44,716 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:643, xmax:721), (ymin:1486, ymax:1685)
# 2022-09-05 18:06:44,997 - stpipe.Extract2dStep - INFO - YYY, (-137, 35), 0
# 2022-09-05 18:06:45,214 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 35 order: 1:
# 2022-09-05 18:06:45,214 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1417.0952494192477, xmax:1427.0952494192477), (ymin:0, ymax:35)
# 2022-09-05 18:06:45,349 - stpipe.Extract2dStep - INFO - YYY, (1362, 1515), 1362
# 2022-09-05 18:06:45,578 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 503 order: 1:
# 2022-09-05 18:06:45,578 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:120.25297702485115, xmax:130.25297702485113), (ymin:1362, ymax:1515)
# 2022-09-05 18:06:45,731 - stpipe.Extract2dStep - INFO - YYY, (1366, 1524), 1366
# 2022-09-05 18:06:45,985 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 505 order: 1:
# 2022-09-05 18:06:45,986 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:661.293237406554, xmax:671.293237406554), (ymin:1366, ymax:1524)
# 2022-09-05 18:06:46,134 - stpipe.Extract2dStep - INFO - YYY, (1330, 1511), 1330
# 2022-09-05 18:06:46,382 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 486 order: 1:
# 2022-09-05 18:06:46,382 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:987, xmax:1072), (ymin:1330, ymax:1511)
# 2022-09-05 18:06:46,523 - stpipe.Extract2dStep - INFO - YYY, (279, 475), 279
# 2022-09-05 18:06:46,874 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 154 order: 1:
# 2022-09-05 18:06:46,874 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:45.50178583245911, xmax:55.50178583245911), (ymin:279, ymax:475)
# 2022-09-05 18:06:47,008 - stpipe.Extract2dStep - INFO - YYY, (1737, 1900), 1737
# 2022-09-05 18:06:47,224 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 622 order: 1:
# 2022-09-05 18:06:47,225 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1689, xmax:1755), (ymin:1737, ymax:1900)
# 2022-09-05 18:06:47,365 - stpipe.Extract2dStep - INFO - YYY, (-154, 16), 0
# 2022-09-05 18:06:47,582 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 33 order: 1:
# 2022-09-05 18:06:47,582 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:126.60255410764367, xmax:136.60255410764367), (ymin:0, ymax:16)
# 2022-09-05 18:06:47,713 - stpipe.Extract2dStep - INFO - YYY, (1018, 1197), 1018
# 2022-09-05 18:06:47,924 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 371 order: 1:
# 2022-09-05 18:06:47,925 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1094, xmax:1138), (ymin:1018, ymax:1197)
# 2022-09-05 18:06:48,061 - stpipe.Extract2dStep - INFO - YYY, (1184, 1353), 1184
# 2022-09-05 18:06:48,429 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 430 order: 1:
# 2022-09-05 18:06:48,430 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1500.0329861456553, xmax:1510.0329861456553), (ymin:1184, ymax:1353)
# 2022-09-05 18:06:48,568 - stpipe.Extract2dStep - INFO - YYY, (1114, 1270), 1114
# 2022-09-05 18:06:48,783 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 408 order: 1:
# 2022-09-05 18:06:48,784 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:411.40380100664703, xmax:421.40380100664703), (ymin:1114, ymax:1270)
# 2022-09-05 18:06:48,917 - stpipe.Extract2dStep - INFO - YYY, (250, 400), 250
# 2022-09-05 18:06:49,132 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 146 order: 1:
# 2022-09-05 18:06:49,133 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1431, xmax:1495), (ymin:250, ymax:400)
# 2022-09-05 18:06:49,270 - stpipe.Extract2dStep - INFO - YYY, (1149, 1327), 1149
# 2022-09-05 18:06:49,482 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 420 order: 1:
# 2022-09-05 18:06:49,483 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1163, xmax:1195), (ymin:1149, ymax:1327)
# 2022-09-05 18:06:49,627 - stpipe.Extract2dStep - INFO - YYY, (1094, 1255), 1094
# 2022-09-05 18:06:49,855 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 400 order: 1:
# 2022-09-05 18:06:49,856 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:532, xmax:583), (ymin:1094, ymax:1255)
# 2022-09-05 18:06:50,148 - stpipe.Extract2dStep - INFO - YYY, (1343, 1516), 1343
# 2022-09-05 18:06:50,371 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 492 order: 1:
# 2022-09-05 18:06:50,371 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1083, xmax:1138), (ymin:1343, ymax:1516)
# 2022-09-05 18:06:50,509 - stpipe.Extract2dStep - INFO - YYY, (1101, 1271), 1101
# 2022-09-05 18:06:50,730 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 402 order: 1:
# 2022-09-05 18:06:50,731 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:642.615214301595, xmax:652.615214301595), (ymin:1101, ymax:1271)
# 2022-09-05 18:06:50,866 - stpipe.Extract2dStep - INFO - YYY, (1114, 1294), 1114
# 2022-09-05 18:06:51,093 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 407 order: 1:
# 2022-09-05 18:06:51,093 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1196, xmax:1242), (ymin:1114, ymax:1294)
# 2022-09-05 18:06:51,225 - stpipe.Extract2dStep - INFO - YYY, (1201, 1374), 1201
# 2022-09-05 18:06:51,439 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 439 order: 1:
# 2022-09-05 18:06:51,440 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1223.0825997333832, xmax:1233.0825997333832), (ymin:1201, ymax:1374)
# 2022-09-05 18:06:51,564 - stpipe.Extract2dStep - INFO - YYY, (1695, 1854), 1695
# 2022-09-05 18:06:51,776 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 612 order: 1:
# 2022-09-05 18:06:51,776 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:748, xmax:794), (ymin:1695, ymax:1854)
# 2022-09-05 18:06:52,071 - stpipe.Extract2dStep - INFO - YYY, (1469, 1623), 1469
# 2022-09-05 18:06:52,281 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 540 order: 1:
# 2022-09-05 18:06:52,281 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1292.8053466456336, xmax:1302.8053466456336), (ymin:1469, ymax:1623)
# 2022-09-05 18:06:52,407 - stpipe.Extract2dStep - INFO - YYY, (323, 481), 323
# 2022-09-05 18:06:52,619 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 162 order: 1:
# 2022-09-05 18:06:52,620 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1663.5303720854317, xmax:1673.5303720854317), (ymin:323, ymax:481)
# 2022-09-05 18:06:52,746 - stpipe.Extract2dStep - INFO - YYY, (907, 1064), 907
# 2022-09-05 18:06:52,960 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 339 order: 1:
# 2022-09-05 18:06:52,960 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:1004.7898323911843, xmax:1014.7898323911843), (ymin:907, ymax:1064)
# 2022-09-05 18:06:53,093 - stpipe.Extract2dStep - INFO - YYY, (1581, 1745), 1581
# 2022-09-05 18:06:53,302 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 570 order: 1:
# 2022-09-05 18:06:53,302 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:899, xmax:931), (ymin:1581, ymax:1745)
# 2022-09-05 18:06:53,431 - stpipe.Extract2dStep - INFO - YYY, (1419, 1588), 1419
# 2022-09-05 18:06:53,643 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 523 order: 1:
# 2022-09-05 18:06:53,644 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:2011.437286260217, xmax:2021.437286260217), (ymin:1419, ymax:1588)
# 2022-09-05 18:06:53,771 - stpipe.Extract2dStep - INFO - YYY, (670, 830), 670
# 2022-09-05 18:06:54,166 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 262 order: 1:
# 2022-09-05 18:06:54,166 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:897, xmax:951), (ymin:670, ymax:830)
# 2022-09-05 18:06:54,296 - stpipe.Extract2dStep - INFO - YYY, (782, 934), 782
# 2022-09-05 18:06:54,514 - stpipe.Extract2dStep - INFO - Subarray extracted for obj: 299 order: 1:
# 2022-09-05 18:06:54,515 - stpipe.Extract2dStep - INFO - Subarray extents are: (xmin:641.7257027087893, xmax:651.7257027087893), (ymin:782, ymax:934)
# 2022-09-05 18:06:55,667 - stpipe.Extract2dStep - INFO - Finished extractions
# 2022-09-05 18:06:55,672 - stpipe.Extract2dStep - INFO - Results used CRDS context: jwst_0968.pmap
# 2022-09-05 18:06:55,673 - stpipe.Extract2dStep - INFO - Step Extract2dStep done
# 'jw01448013001_02105_00001_nis_ex2d.fits'

# %% [markdown]
# ##### Plots
#
# Plot the grism image with the bounding_boxes (cutouts) of the individual slits and the location of the sources.

# %%
ax = plt.subplot()
ax.imshow(out.data, aspect='auto', vmin=-1, vmax=1.4, origin='lower')
plt.gray()

for slit in exout.slits:
    ax.scatter(slit.source_xpos, slit.source_ypos)
    bbox = slit.meta.wcs.bounding_box
    xstart, ystart = slit.xstart, slit.ystart
    ax.add_patch(patches.Rectangle((bbox[0][0]+xstart-1, bbox[1][0]+ystart-1), 
                                   bbox[0][1]-bbox[0][0], bbox[1][1]-bbox[1][0], edgecolor='g',
                                   fill=False))

plt.gray()
# Out:
# <img src="data:image/png;base64,..." width="640">
